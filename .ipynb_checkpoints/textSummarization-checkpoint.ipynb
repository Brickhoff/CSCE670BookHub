# %%
import re
import math
import numpy as np
import requests

from textblob import TextBlob
from wordfreq import word_frequency
from bs4 import BeautifulSoup
import pandas as pd
from nltk.corpus import stopwords
from gensim.summarization import summarize
from gensim.summarization.textcleaner import clean_text_by_sentences

from gensim.summarization import keywords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/stjiao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# extract review from good read
# TODO : a list of reviews
def extractReview(isbn):
    searchHeader="https://www.goodreads.com/search?q="
    response = requests.get(searchHeader+isbn)
    soup = BeautifulSoup(response.text, 'lxml')
    review_divs = soup.findAll('div', {'class' :'reviewText stacked'})
    reviews = []
    for div in review_divs:
#         print(div.findAll('span'))
        if len(div.findAll('span')) < 3:
            continue
        review = div.findAll('span')[2]
        reviews.append("".join(review.strings).strip())
        if len(reviews) > 10:
            break
    return reviews
#     print(response.text)
#     address = soup.find('div', {'class' :'reviewFooter uitext buttons'}).findAll('a')[3]['href']
#     print(address)
#     reviews = []
    
#     header = "https://www.goodreads.com"
#     review_response = requests.get(header+address)
#     soup2 = BeautifulSoup(review_response.text, 'lxml')
#     res = soup2.find('div', {'class' :'reviewText mediumText description readable'})
#     print("".join(res.strings))
    
#     return "".join(res.strings).strip()

# %%
# extract description from good read TODO
def extractDescpription(isbn):
    searchHeader="https://www.goodreads.com/search?q="
    response = requests.get(searchHeader+isbn)
    soup = BeautifulSoup(response.text, 'lxml')
    desc = soup.find('div', {'id' :'description'}).findAll('span')
    if len(desc) < 2:
         index = 0
    else:
        index = 1
    return "".join(desc[index].strings).strip()
#     print(response.text)
#     address = soup.find('div', {'class' :'reviewFooter uitext buttons'}).findAll('a')[3]['href']
#     print(address)
    
#     header = "https://www.goodreads.com"
#     review_response = requests.get(header+address)
#     soup2 = BeautifulSoup(review_response.text, 'lxml')
#     res = soup2.find('div', {'class' :'reviewText mediumText description readable'})
#     print("".join(res.strings))
    
#     return "".join(res.strings).strip()

# %%
extractDescpription("0517548233")
# Out:
# 'A million copy seller, Henry Hazlitt’s Economics in One Lesson is a classic economic primer. But it is also much more, having become a fundamental influence on modern “libertarian” economics of the type espoused by Ron Paul and others.Considered among the leading economic thinkers of the “Austrian School,” which includes Carl Menger, Ludwig von Mises, Friedrich (F.A.) Hayek, and others, Henry Hazlitt (1894-1993), was a libertarian philosopher, an economist, and a journalist. He was the founding vice-president of the Foundation for Economic Education and an early editor of The Freeman magazine, an influential libertarian publication.\xa0 Hazlitt wrote Economics in One Lesson, his seminal work, in 1946. Concise and instructive, it is also deceptively prescient and far-reaching in its efforts to dissemble economic fallacies that are so prevalent they have almost become a new orthodoxy.Many current economic commentators across the political spectrum have credited Hazlitt with foreseeing the collapse of the global economy which occurred more than 50 years after the initial publication of Economics in One Lesson. Hazlitt’s focus on non-governmental solutions, strong — and strongly reasoned — anti-deficit position, and general emphasis on free markets, economic liberty of individuals, and the dangers of government intervention make Economics in One Lesson, every bit as relevant and valuable today as it has been since publication.'

# %%
review=extractReview("0517548233")[0]

# %%
# from contextlib import closing
# from selenium.webdriver import Chrome # pip install selenium
# from selenium.webdriver.support.ui import WebDriverWait
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support import expected_conditions as EC

# from selenium import webdriver
# driver = webdriver.Chrome(executable_path=r'/Users/stjiao/2019Spring/670project/chromedriver')
# driver.get(searchHeader+isbn)
# button = driver.find_element_by_id('description')


# button.find_element_by_tag_name('a').click()

# element = WebDriverWait(driver, 10).until(
# EC.invisibility_of_element_located((By.ID, "deviceShowAllLink"))
# )
# # store it to string variable
# page_source = driver.page_source

# soup = BeautifulSoup(page_source, 'lxml')
# res = soup.find('div', {'id' :'description'})

# res

# %%
# transform review into a list of sentences
def Review2sen(review):
#     blob = TextBlob(" ".join(review))
#     sentences = [item.raw for item in blob.sentences]
#     sentences = [" ".join(["".join(w.split(" ")) for w in item.split("  ")]) for item in sentences]
    raw = clean_text_by_sentences(review)
    sentences = []
    for i in range(0,len(raw)):
        sentences.append(raw[i].text)
    return sentences

# %%
sentences = Review2sen(review)

# %%
stopwords = set(stopwords.words('english'))

# %%
count = {}
for i in range(0,len(sentences)):
    blob = TextBlob(sentences[i])
    for word in blob.words:
        word = word.lower()
        if word in stopwords:
            continue
        if word not in count:
            count[word] = {}
        if i not in count[word]:
            count[word][i] = 0
        count[word][i] = count[word][i] + 1

countMap = pd.DataFrame(data = count)

countMap = countMap.fillna(0)

# %%
# review = review.replace('n\'t','not')

# %% [markdown]
# ## TF-IDF and BM25 base tag method

# %%
puncs = set(("\'s","\'re","n't"))

# %%
word_score = {}
for word in countMap.columns:
    if word in puncs:
        continue
    df = word_frequency(word, 'en')
    if df == 0.0:
        word_score[word] = 0
        continue
    print(df)
    idf = math.log(1.0/df,math.e)
    tf = (countMap[word] != 0).sum()
    weight = tf * idf
    word_score[word] = weight

word_score_sorted = sorted(word_score, key=word_score.get, reverse=True)
# Out:
# 0.000589
# 0.000339
# 0.00129
# 0.000224
# 0.000759
# 7.24e-07
# 5.37e-05
# 0.000355
# 0.000148
# 0.000123
# 0.000389
# 2.19e-05
# 0.00012
# 0.000148
# 0.000575
# 0.000316
# 0.000309
# 0.000363
# 5.75e-05
# 0.000832
# 0.000178
# 0.0011
# 0.000275
# 0.00135
# 0.000631
# 1.12e-05
# 3.09e-06
# 0.000166
# 0.000324
# 0.000324
# 0.000195
# 5.01e-07
# 1.12e-05
# 5.13e-08
# 0.0017
# 0.000331
# 7.59e-06
# 4.57e-05
# 0.000355
# 2.82e-06
# 4.17e-06
# 1.38e-06
# 3.72e-05
# 1.35e-05
# 7.94e-05
# 2.82e-07
# 5.37e-05
# 0.000145
# 0.000178
# 0.000219
# 3.24e-06
# 0.000275
# 0.000257
# 2e-05
# 0.000219
# 0.000977
# 1.51e-05
# 4.47e-05
# 0.00107
# 2.14e-06
# 4.57e-05
# 0.000339
# 3.02e-06
# 0.000331
# 3.47e-05
# 0.000282
# 0.000151
# 0.000263
# 0.00102
# 0.000117
# 1.7e-05
# 2.51e-08
# 0.00129
# 0.000162
# 0.000776
# 1.51e-05
# 3.47e-07
# 4.57e-06
# 0.000174
# 5.25e-06
# 0.00049
# 0.000575
# 0.000562
# 0.000158
# 8.13e-06
# 0.000331
# 1.74e-05
# 0.00182
# 7.41e-05
# 0.000138
# 7.41e-05
# 6.92e-07
# 3.89e-05
# 3.39e-05
# 5.13e-06
# 4.37e-06
# 0.000479
# 0.000191
# 2.63e-05
# 6.46e-07
# 3.24e-05
# 5.75e-06
# 6.17e-05
# 0.000269
# 8.32e-05
# 1.91e-05
# 7.08e-06
# 2.88e-05
# 1.74e-06
# 5.5e-05
# 1.78e-05
# 5.5e-06
# 6.61e-05
# 1.35e-06
# 7.24e-05
# 0.000117
# 2e-05
# 8.13e-06
# 5.01e-05
# 9.33e-05
# 3.63e-05
# 0.000166
# 1.15e-05
# 0.000115
# 0.000209
# 0.000832
# 0.000151
# 0.000288
# 6.03e-06
# 1.58e-06
# 0.000145
# 1.12e-05
# 0.000107
# 1.38e-05
# 4.17e-07
# 3.39e-06
# 1.23e-05
# 7.76e-07
# 0.000138
# 0.000813
# 4.68e-06
# 2.19e-05
# 2.03e-05
# 5.59e-05
# 3.47e-05
# 0.000295
# 0.000234
# 0.000148
# 0.00191
# 0.00012
# 2.29e-06
# 0.00017
# 0.000437
# 7.24e-06
# 7.08e-05
# 3.8e-05
# 1.48e-05
# 3.47e-05
# 0.000107
# 0.00107
# 8.32e-07
# 0.000257
# 0.000155
# 0.000191
# 4.57e-05
# 3.63e-05
# 5.25e-06
# 2.75e-05
# 1.91e-05
# 0.000214
# 2.51e-05
# 2.82e-06
# 5.25e-06
# 0.000851
# 4.79e-05
# 3.63e-06
# 0.000214
# 8.51e-05
# 3.24e-05
# 4.52e-05
# 0.000123
# 0.000245
# 0.000107
# 7.94e-05
# 6.61e-06
# 3.09e-05
# 0.000219
# 8.51e-05
# 0.000282
# 5.62e-06
# 1.26e-05
# 2.14e-06
# 5.13e-05
# 4.37e-07
# 5.37e-05
# 2.75e-07
# 0.000138
# 5.37e-06
# 3.8e-07
# 4.68e-06
# 0.00012
# 0.000204
# 0.000117
# 0.000479
# 5.89e-05
# 5.13e-05
# 0.000537
# 1.23e-05
# 1.1e-05
# 0.000324
# 8.51e-06
# 1.2e-05
# 1.23e-05
# 2.95e-06
# 0.000132
# 2.69e-05
# 0.000331
# 2.82e-05
# 1.74e-05
# 7.08e-05

# %%
allowed_words = word_score_sorted[:int(countMap.shape[0]*0.2)]

# %%
# get weight,idf,tf for query_term
def TfIdfScore(query_term,sentence,countMap):
#  get term freq
    tf = 0
    for word in sentence:
        if word.lower() == query_term:
            tf= tf + 1
    if (tf == 0) :
        return 0,0,0
    
#     get idf
#     print(tf)
#     df = countMap[query_term]
    df = (countMap[query_term] != 0).sum()
    idf = math.log(countMap.shape[0]/df,math.e)
#     weight = (1 + math.log(tf,math.e)) * idf
    weight = (tf) * idf
#     print(idf)
#     print(df)

    return weight,tf,idf

# %%
avgdl = 0.0
for i in range(0,countMap.shape[0]):
    blob = TextBlob(sentences[i])
    avgdl = avgdl + len(blob.words)
#     print(avgdl)
avgdl = avgdl / countMap.shape[0]
avgdl
# Out:
# 18.27922077922078

# %%
def BM25scoreWrapper(input_avgdl):
    def BM25score(query_term,sentence,countMap,avgdl=input_avgdl,k1=1.2,b=0.75):
        weight,tf,idf = TfIdfScore(query_term,sentence,countMap)
        doclen = len(sentence)
        return idf * (tf * (k1 + 1)) / (tf + k1 * (1- b + b * doclen/avgdl)),tf,idf
    return BM25score

# %%
def BM25score(query_term,sentence,countMap,avgdl,k1=1.2,b=0.75):
    weight,tf,idf = TfIdfScore(query_term,sentence,countMap)
#     blob = TextBlob(sentence)
    doclen = len(sentence)
    return idf * (tf * (k1 + 1)) / (tf + k1 * (1- b + b * doclen/avgdl)),tf,idf

# %%
def sentenceScore(sentences, scoreFunc,allowedWords = {}):
    senScore = {}
    for i in range(0,len(sentences)):
        blob = TextBlob(sentences[i])
        senScore[i] = 0.0
        for word in blob.words:
            word = word.lower()
            if word in stopwords:
                continue
            if allowedWords != {} and word not in allowedWords:
                continue
#             print(scoreFunc(word,blob.words,countMap)[0])
            senScore[i] = senScore[i] + scoreFunc(word,blob.words,countMap)[0]
    sen_sorted = sorted(senScore, key=senScore.get, reverse=True)
    
    return senScore,sen_sorted

# %%
indexes = sentenceScore(sentences,TfIdfScore,allowed_words)[1]

# %%
def indexes2Sum(indexes,sentences):
    res = ""
    sorted_indexes = sorted(indexes[:10])
    for index in sorted_indexes:
        res = res + sentences[index]
    return res

# %%
indexes2Sum(indexes,sentences)
# Out:
# 'The things Hazlitt is talking about, by definition, cannot be measured in the way you\'re asking, because they are never permitted to come into being." In other words, Hazlitt doesnot need facts as he has already made clear that he is entitled to imagine counterfactuals.Well, if we are going to look at things that might have happened or not happened, here\'re some other counterfactuals for consideration:Counterfactual #1:The government builds a bridge.It decides against it, and instead decides to invest by bidding for a construction infrastructure job in China where the government subsidies make the job more profitable.Any profits made from that job go into the pockets of a subsidiary set up in a tax-free haven to evade US taxes--something which makes jobs for lawyers and no one else--and the management go on a spending spree buying a huge $20 million customised yacht made by a specialist company that employs 10 people.Deflation is destroying company profits but a brave company decides to invest in building a bridge.Its management, who are far-sighted, prudent and economical (because, you know, all management are like that), decide to pay themselves a small sum because they decide that over 20 years, the investment will reap more rewards.Even though the economy is suffering a brutal recession, and things look still uncertain, some entrepeurnerial people decide to throw off their caution and their gloom to start new industries by spending their capital that they had been diligently saving away during the recession.After five years, a non-predatory investment company (because the predatory kind doesnot exist right?) looks at the low share price of the company (due to its small profits) and decides that while it would be a highly profit-making investment to acquire the company and jack up tolls it wonot do this because that would be bad for the economy.Hazlitt is being intellectually dishonest (or just plain ideological) when he cherry picks his counterfactual to give the impression that the only—albeit unseen—result of government projects is to destroy private sector jobs.It’s not even that companies want to create more jobs: Companies aren’t hiring because a company that has only demand for 10 widgets that can be made by five people is not going to be hiring 10 people at half pay to do the job.'

# %%
sentenceScore(sentences,TfIdfScore)
# Out:
# ({0: 53.34177839334511,
#   1: 25.998153013372736,
#   2: 31.785050394739446,
#   3: 60.5743685159249,
#   4: 0.0,
#   5: 22.009168966808463,
#   6: 62.34755159958002,
#   7: 123.42659187369652,
#   8: 15.656501931931956,
#   9: 3.0143086591269266,
#   10: 60.84347420280375,
#   11: 50.25050869308205,
#   12: 43.36499902304723,
#   13: 12.10319677207234,
#   14: 39.669965703358926,
#   15: 102.23649836681732,
#   16: 36.47333548743804,
#   17: 9.660849736703137,
#   18: 42.308946348797924,
#   19: 31.663864837937226,
#   20: 30.943906399926618,
#   21: 53.18592470759702,
#   22: 15.6300686748638,
#   136: 40.851616214561275,
#   137: 54.151405683661935,
#   138: 30.491921276183565,
#   139: 40.363112883918866,
#   140: 12.883355329621917,
#   141: 65.05011827323304,
#   142: 21.192084885017756,
#   143: 39.01503973561918,
#   144: 23.389309462353975,
#   145: 12.10319677207234,
#   146: 11.369227596992141,
#   147: 53.2586634866346,
#   148: 58.85551581750493,
#   149: 75.34356725285595,
#   150: 56.170096272303695,
#   151: 112.2829924702186,
#   152: 19.16980175717787,
#   153: 20.991414189555606,
#   154: 33.17772586833845,
#   155: 113.27409562454346,
#   156: 67.24288850021988,
#   157: 45.92172657292698,
#   158: 45.98626509406456,
#   159: 40.965421664065886,
#   160: 91.79534877237955,
#   161: 62.22976856392363,
#   162: 46.10122010111614,
#   163: 44.386421673024216,
#   164: 44.20410011623026},
#  [77,
#   7,
#   105,
#   155,
#   151,
#   40,
#   15,
#   109,
#   160,
#   102,
#   117,
#   135,
#   116,
#   149,
#   98,
#   86,
#   118,
#   59,
#   75,
#   156,
#   141,
#   89,
#   103,
#   45,
#   6,
#   161,
#   10,
#   3,
#   49,
#   148,
#   60,
#   42,
#   150,
#   54,
#   28,
#   137,
#   106,
#   0,
#   36,
#   147,
#   21,
#   100,
#   134,
#   95,
#   129,
#   133,
#   11,
#   87,
#   92,
#   76,
#   162,
#   158,
#   157,
#   43,
#   78,
#   44,
#   73,
#   163,
#   52,
#   164,
#   93,
#   84,
#   12,
#   18,
#   48,
#   115,
#   110,
#   159,
#   136,
#   124,
#   139,
#   14,
#   65,
#   79,
#   63,
#   74,
#   143,
#   112,
#   37,
#   108,
#   122,
#   24,
#   81,
#   41,
#   16,
#   64,
#   61,
#   29,
#   53,
#   154,
#   2,
#   19,
#   107,
#   47,
#   20,
#   138,
#   25,
#   121,
#   56,
#   72,
#   62,
#   32,
#   120,
#   38,
#   66,
#   1,
#   55,
#   57,
#   99,
#   114,
#   144,
#   69,
#   128,
#   46,
#   5,
#   39,
#   91,
#   142,
#   153,
#   126,
#   96,
#   27,
#   125,
#   88,
#   130,
#   85,
#   90,
#   80,
#   71,
#   104,
#   152,
#   26,
#   67,
#   31,
#   97,
#   127,
#   111,
#   70,
#   8,
#   22,
#   58,
#   35,
#   113,
#   131,
#   140,
#   82,
#   123,
#   13,
#   94,
#   119,
#   145,
#   146,
#   101,
#   34,
#   68,
#   17,
#   83,
#   23,
#   50,
#   132,
#   51,
#   30,
#   9,
#   4,
#   33])

# %%
sentenceScore(sentences,BM25scoreWrapper(avgdl),allowed_words)
# Out:
# ({0: 0.0,
#   1: 0.0,
#   2: 0.0,
#   3: 3.0659472312931624,
#   4: 0.0,
#   5: 7.136142711937767,
#   6: 2.2027176981891117,
#   7: 0.0,
#   8: 4.436062654340419,
#   9: 4.721762351188204,
#   10: 0.0,
#   11: 0.0,
#   12: 0.0,
#   13: 5.224695703296755,
#   14: 7.392528167033915,
#   15: 7.920256722373825,
#   16: 0.0,
#   17: 6.173751786826598,
#   18: 1.9691535953115518,
#   19: 6.003370970562693,
#   20: 2.889463185760443,
#   21: 4.7679829924304205,
#   22: 2.4339562219120414,
#   23: 0.0,
#   145: 0.0,
#   146: 0.0,
#   147: 0.0,
#   148: 9.368712263682497,
#   149: 5.100563255589594,
#   150: 11.429290197947296,
#   151: 8.560905116740892,
#   152: 2.581191342980918,
#   153: 3.5608610020318596,
#   154: 8.349333482039933,
#   155: 13.186719841283068,
#   156: 1.7222916900453977,
#   157: 0.0,
#   158: 6.762092153026632,
#   159: 4.328200444527402,
#   160: 3.5725771439041543,
#   161: 0.0,
#   162: 2.2051592512667724,
#   163: 2.2051592512667724,
#   164: 6.118098998995588},
#  [79,
#   45,
#   80,
#   155,
#   88,
#   116,
#   49,
#   57,
#   109,
#   75,
#   137,
#   150,
#   95,
#   141,
#   77,
#   110,
#   105,
#   63,
#   72,
#   73,
#   136,
#   101,
#   102,
#   134,
#   81,
#   148,
#   74,
#   104,
#   44,
#   151,
#   92,
#   154,
#   135,
#   133,
#   15,
#   138,
#   14,
#   43,
#   5,
#   93,
#   130,
#   66,
#   55,
#   96,
#   158,
#   58,
#   65,
#   118,
#   86,
#   46,
#   100,
#   17,
#   143,
#   164,
#   108,
#   103,
#   19,
#   78,
#   84,
#   64,
#   41,
#   62,
#   60,
#   112,
#   115,
#   13,
#   50,
#   149,
#   24,
#   91,
#   106,
#   21,
#   9,
#   98,
#   132,
#   8,
#   89,
#   159,
#   48,
#   47,
#   71,
#   97,
#   38,
#   111,
#   42,
#   129,
#   142,
#   121,
#   117,
#   140,
#   37,
#   31,
#   126,
#   160,
#   153,
#   119,
#   53,
#   61,
#   29,
#   122,
#   128,
#   90,
#   3,
#   20,
#   25,
#   87,
#   76,
#   26,
#   152,
#   107,
#   22,
#   28,
#   27,
#   162,
#   163,
#   6,
#   54,
#   18,
#   156,
#   0,
#   1,
#   2,
#   4,
#   7,
#   10,
#   11,
#   12,
#   16,
#   23,
#   30,
#   32,
#   33,
#   34,
#   35,
#   36,
#   39,
#   40,
#   51,
#   52,
#   56,
#   59,
#   67,
#   68,
#   69,
#   70,
#   82,
#   83,
#   85,
#   94,
#   99,
#   113,
#   114,
#   120,
#   123,
#   124,
#   125,
#   127,
#   131,
#   139,
#   144,
#   145,
#   146,
#   147,
#   157,
#   161])

# %% [markdown]
# ### gensim method

# %%
from gensim.summarization import summarize
from gensim.summarization.textcleaner import clean_text_by_sentences

from gensim.summarization import keywords

# %%
# evaluate our resulrt base on the distance A= dist from original review to description, 
# distance B = dist from original review to summary

# %%
sentences[79]
# Out:
# 'Deflation is destroying company profits but a brave company decides to invest in building a bridge.'

# %%
print(summarize(review))
# Out:
# On a hypothetical of government building a bridge:But if we have trained ourselves to look beyond immediate to secondary consequences, and beyond those who are directly benefitted by a government project to others who are indirectly affected, a different picture presents itself.
# The things Hazlitt is talking about, by definition, cannot be measured in the way you're asking, because they are never permitted to come into being." In other words, Hazlitt doesn't need facts as he has already made clear that he is entitled to imagine counterfactuals.
# Well, if we are going to look at things that might have happened or not happened, here're some other counterfactuals for consideration:Counterfactual #1:The government builds a bridge.
# The increase in income both in terms of more jobs and more profits generates revenue for the government that more than pays for the cost of the bridge even without raising taxes.
# Counterfactual #2:On the other hand, a private company builds a bridge.
# Some extra jobs are created, but income is largely diverted into the costs of paying the toll of the company.
# A company looks into the possibility of building a bridge across the valley thinking it might be a good investment opportunity.
# After doing its sums, it decides that the return on investment will be too low since the economy is rotten and people aren't consuming.
# Any profits made from that job go into the pockets of a subsidiary set up in a tax-free haven to evade US taxes--something which makes jobs for lawyers and no one else--and the management go on a spending spree buying a huge $20 million customised yacht made by a specialist company that employs 10 people.
# Deflation is destroying company profits but a brave company decides to invest in building a bridge.
# After looking at the business plan, the bank refuses the loan because it decides the risk is too high.
# Not only were they not in a position to invest in new opportunities (thereby creating more jobs), some perfectly good companies faced potential shut-down when revolving credit facilities were turned off.
# To save costs, the company had cut corners on building the bridge which due to lack of repair collapses.
# Counterfactual #7:Well, I guess if we are going to be playing faith-based economics, why not an optimistic free trade scenario?
# A company decides to build the bridge.
# They decide to charge a small toll--enough to cover interest and repayment of principle for the first five years--to encourage people to use the bridge.
# The low costs encourage people to use the bridge.
# Even though the economy is suffering a brutal recession, and things look still uncertain, some entrepeurnerial people decide to throw off their caution and their gloom to start new industries by spending their capital that they had been diligently saving away during the recession.
# After five years, a non-predatory investment company (because the predatory kind doesn't exist right?) looks at the low share price of the company (due to its small profits) and decides that while it would be a highly profit-making investment to acquire the company and jack up tolls it won't do this because that would be bad for the economy.
# After 10 years, the company decides to raise the toll by 20% taking into account the strengthening economy.
# Hazlitt is being intellectually dishonest (or just plain ideological) when he cherry picks his counterfactual to give the impression that the only—albeit unseen—result of government projects is to destroy private sector jobs.
# Companies are actively looking to invest and grow new businesses, so we anticipate that jobs will come slowly but gradually.
# To fund this, the government announces that it will raise taxes across the board rather than funding it by using anticipated incoming tolls since it expects no one will use the bridge anyway.
# Rather than outsource the job to the private sector, it decides to set up a Department of Building this Single Bridge.
# To attract people to build this bridge where the economy has other jobs on offer, it has to offer salaries over and above what the private sector is offering.
# Because of this, people give up jobs and companies are left strapped and short of labour.
# The private sector starts to cut jobs anyway to service the additional costs of the taxes imposed as their profit margins are very small, and they are barely scraping by.
# Credit is tight because banks aren’t lending, so companies cannot invest to create more jobs.
# More likely, it will fire two of the five and make the remaining three people work harder for less pay in anticipation of a possible further decline in demand.
# People that have jobs cling to them and save up for a rainy day, making do with the minimum in essentials, rather than spending more.In that situation, a government could just leave the economy to contract and hopefully self-correct at some time in the future.

# %%
gen_sum = summarize(review,split = True)

indexes = []
for i in range(0,len(gen_sum)):
    for j in range(0,len(sentences)):
        if gen_sum[i] == sentences[j]:
            indexes.append(j)
            break

# %%
indexes
# Out:
# [14,
#  39,
#  40,
#  44,
#  51,
#  57,
#  60,
#  67,
#  68,
#  71,
#  73,
#  80,
#  87,
#  94,
#  95,
#  97,
#  98,
#  99,
#  102,
#  103,
#  108,
#  124,
#  126,
#  127,
#  128,
#  129,
#  132,
#  144,
#  146,
#  148]

# %%
# extension:sentiment analysis

# %%
print(keywords(review))
# Out:
# company
# companies
# people
# profit
# profitable
# job
# jobs
# government
# governments
# profits generates
# counterfactuals
# counterfactual
# bank
# banks
# investment
# invest
# investments
# costs
# cost
# new
# hazlitt thinks
# thinking
# good
# goods
# business
# businesses
# country
# countries
# possibility
# possible
# free
# doesnot
# donot think
# workers
# life
# based
# mind
# credit
# rhetoric
# way
# ways
# consuming
# consumer
# happen
# happened
# happening
# taxes
# tax
# economics
# economical
# economic
# makes
# making
# original
# causes
# causing
# spend
# spending
# saving
# savings
# save
# low
# better
# different
# bridge
# bridges
# economy
# economies
# things
# thing
# demand
# increase
# increases
# martial
# conclusions
# added
# canal
# portions
# japan
# recession
# self
# mode
# answers
# immigration
# immigrate
# policy
# unseen
# looking
# look
# looks
# nuclear
# labour
# decides
# decide
# generated
# destroyed
# destroying
# destroy
# trade
# sector
# raising
# raises
# raise
# transport
# scenario
# private
# million customised
# little boy
# particular
# situation
# loan
# toll
# tolls
# healthy
# small
# predatory
# income
# incoming
# real
# reviewi
# robber
# needed
# need

# %%
# a various of language

# %%
# countMap.fillna(0)

# %% [markdown]
# ## Matrix Factorization

# %%
R_train = np.zeros(countMap.shape)

# R[:] = np.nan

# R

for i in range(0,countMap.shape[0]):
    for j in range(0,countMap.shape[1]):
        R_train[i][j] = countMap.iloc[i,j]*100



R_train = R_train.transpose()

# %%
R_train.shape
# Out:
# (808, 154)

# %%
>>> from sklearn.decomposition import NMF
>>> model = NMF(n_components=10, init='random', random_state=0)
>>> W = model.fit_transform(R_train)
>>> H = model.components_

# %%
H.shape
# Out:
# (10, 154)

# %%
W.shape
# Out:
# (808, 10)

# %%
indexes = H.sum(axis = 0).argsort()[-10:][::-1]

# %%
indexes2Sum(list(indexes),sentences)
# Out:
# 'Sorry, whether it\'s libertarian mind games or socialist mind games, it\'s all just mind games.But for heaven’s sakes, let’s not pretend that theoretical assumptions and inferences based on those assumptions are the same thing as the price you paid for today\'s lunch or the number of shirts you have in your wardrobe.The things Hazlitt is talking about, by definition, cannot be measured in the way you\'re asking, because they are never permitted to come into being." In other words, Hazlitt doesnot need facts as he has already made clear that he is entitled to imagine counterfactuals.Any profits made from that job go into the pockets of a subsidiary set up in a tax-free haven to evade US taxes--something which makes jobs for lawyers and no one else--and the management go on a spending spree buying a huge $20 million customised yacht made by a specialist company that employs 10 people.Its management, who are far-sighted, prudent and economical (because, you know, all management are like that), decide to pay themselves a small sum because they decide that over 20 years, the investment will reap more rewards.Even though the economy is suffering a brutal recession, and things look still uncertain, some entrepeurnerial people decide to throw off their caution and their gloom to start new industries by spending their capital that they had been diligently saving away during the recession.After five years, a non-predatory investment company (because the predatory kind doesnot exist right?) looks at the low share price of the company (due to its small profits) and decides that while it would be a highly profit-making investment to acquire the company and jack up tolls it wonot do this because that would be bad for the economy.One situation where the economic effects of Hazlitt’s example could play out as described by him is as follows: We have an economy which is growing.So, Hazlitt’s scenario can be true, but—dependent as it is on a number of factors—it’s hardly the only possible scenario.However, the more important question is whether the facts on the ground at that point in time and in that particular situation match this scenario (or are materially similar) or whether the facts on the ground show something else.'

# %% [markdown]
# ## PyTeaser

# %%
>>> from textteaser import TextTeaser
>>> tt = TextTeaser()
>>> tt.summarize(title, text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-249-0974f61d9f50> in <module>()
# ----> 1 from textteaser import TextTeaser
#       2 tt = TextTeaser()
#       3 tt.summarize(title, text)
#
# ModuleNotFoundError: No module named 'textteaser'
